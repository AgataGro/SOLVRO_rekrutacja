# %%
import pandas as pd

# %%
df = pd.read_csv('predictions.csv')

print(df.to_string())
# Out:
#            1;0
# 0          2;3
# 1          3;3
# 2          4;3
# 3          5;3
# 4          6;2
# 5          7;3
# 6          8;1
# 7          9;0
# 8         10;3
# 9         11;3
# 10        12;1
# 11        13;2
# 12        14;1
# 13        15;1
# 14        16;3
# 15        17;2
# 16        18;2
# 17        19;1
# 18        20;4
# 19        21;3
# 20        22;3
# 21        23;3
# 22        24;1
# 23        25;1
# 24        26;2
# 25        27;1
# 26        28;1
# 27        29;2
# 28        30;3
# 29        31;1
# 30        32;2
# 31        33;3
# 32        34;2
# 33        35;0
# 34        36;1
# 35        37;1
# 36        38;2
# 37        39;2
# 38        40;1
# 39        41;1
# 40        42;1
# 41        43;2
# 42        44;2
# 43        45;3
# 44        46;2
# 45        47;1
# 46        48;2
# 47        49;1
# 48        50;3
# 49        51;2
# 50        52;3
# 51        53;0
# 52        54;4
# 53        55;2
# 54        56;3
# 55        57;3
# 56        58;2
# ...
